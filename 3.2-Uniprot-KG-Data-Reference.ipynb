# %% [markdown]
# ### Uniprot KG Data Builder

# %%
import gzip
import pandas as pd
import json as json
import os

# %% [markdown]
# #### Read Json file (one file element at a time)

# %%
with open("data/output/all_uniprot_data.json", "r") as f:
    uniprot_data = json.load(f)

# %% [markdown]
# - How amny data points are there? What are the keys?

# %%
print("Data Points: ",len(uniprot_data),"|",  "Keys:" , uniprot_data[0].keys())
# Out:
# Data Points:  569516 | Keys: dict_keys(['accession', 'name', 'gene', 'organism', 'sequence', 'uniprotId', 'ptm', 'references'])

# %% [markdown]
# ### Prepare subset of data with PTM record

# %% [markdown]
# First we select the PTM associated data and flatten the dictionary to create three columns seperately: Position, description, evicence

# %%
REF_DATA = []
for item in uniprot_data:
    if item['ptm'] != []:
        data = {}
        data['gene'] = item['gene']
        data['name'] = item['name']
        data['organism'] = item['organism']
        data['uniprotId'] = item['uniprotId']
       
        # create key to reference mapping
        key2ref = {}
        for ref in item['references']:
            key2ref[ref['key']] = ref

        
        for ptm in item['ptm']:
            #print(ptm)
            idata = data.copy()
            try:
                idata['position'] = ptm['Position']
            except:
                idata['position'] = None
            try:
                idata['description'] = ptm['Description']
            except:
                idata['description'] = None
            try:
                idata['evidence'] = ptm['Evidence']
            except:
                idata['evidence'] = None

            if idata['evidence'] != None:

                # get reference keys by splitting the evidences string
                ref_keys = ptm['Evidence'].split(' ')

                # apply key2fer mapping to get reference data
                modified_residue_ref = [key2ref[ref] for ref in ref_keys if ref in key2ref.keys()]

                
                for ref_item in modified_residue_ref:
                    #print(ref_item)
                    idata_ref = idata.copy()
                    if 'pubmedId' in ref_item.keys():
                        idata_ref['pubmedId'] = ref_item['pubmedId']
                        idata_ref['journal'] = ref_item['journal']
                        idata_ref['title'] = ref_item['title']
                        idata_ref['date'] = ref_item['date']
                    else:
                        idata_ref['pubmedId'] = None
                        idata_ref['journal'] = None
                        idata_ref['title'] = None
                        idata_ref['date'] = None
                        
                    REF_DATA.append(idata_ref)

# %%
REF_DATA
# Out:
# [{'gene': 'scly',
#   'name': 'Selenocysteine lyase',
#   'organism': 'Xenopus tropicalis',
#   'uniprotId': 'Q5U4Q9',
#   'position': '239',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '1',
#   'description': 'N-acetylmethionine',
#   'evidence': '17 25 26',
#   'pubmedId': '25944712',
#   'journal': 'Proteomics',
#   'title': None,
#   'date': '2015'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '1',
#   'description': 'N-acetylmethionine',
#   'evidence': '17 25 26',
#   'pubmedId': '16773128',
#   'journal': 'Eur. J. Hum. Genet.',
#   'title': None,
#   'date': '2006'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '1',
#   'description': 'N-acetylmethionine',
#   'evidence': '17 25 26',
#   'pubmedId': '18804074',
#   'journal': 'J. Genet. Genomics',
#   'title': None,
#   'date': '2008'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '22223895',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '22814378',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '26228148',
#   'journal': 'Science',
#   'title': None,
#   'date': '2015'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '30028079',
#   'journal': 'FEBS J.',
#   'title': None,
#   'date': '2018'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '14684684',
#   'journal': 'J. Med. Genet.',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '16773128',
#   'journal': 'Eur. J. Hum. Genet.',
#   'title': None,
#   'date': '2006'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '18804074',
#   'journal': 'J. Genet. Genomics',
#   'title': None,
#   'date': '2008'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '2',
#   'description': 'N-acetylglutamate; in Actin, cytoplasmic 2, N-terminally processed; partial',
#   'evidence': '14 15 18 19 24 25 26 27',
#   'pubmedId': '19477959',
#   'journal': 'Hum. Mol. Genet.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '44',
#   'description': 'Methionine (R)-sulfoxide',
#   'evidence': '1',
#   'pubmedId': '3737401',
#   'journal': 'Nucleic Acids Res.',
#   'title': None,
#   'date': '1986'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '47',
#   'description': 'Methionine (R)-sulfoxide',
#   'evidence': '1',
#   'pubmedId': '3737401',
#   'journal': 'Nucleic Acids Res.',
#   'title': None,
#   'date': '1986'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '73',
#   'description': 'Tele-methylhistidine',
#   'evidence': '16 19',
#   'pubmedId': '23673617',
#   'journal': 'Nat. Commun.',
#   'title': None,
#   'date': '2013'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '73',
#   'description': 'Tele-methylhistidine',
#   'evidence': '16 19',
#   'pubmedId': '30028079',
#   'journal': 'FEBS J.',
#   'title': None,
#   'date': '2018'},
#  {'gene': 'ACTG1',
#   'name': 'Actin, cytoplasmic 2',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63261',
#   'position': '84',
#   'description': 'N6-methyllysine',
#   'evidence': '11',
#   'pubmedId': '14654843',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'prfA',
#   'name': 'Peptide chain release factor 1',
#   'organism': 'Salmonella choleraesuis (strain SC-B67)',
#   'uniprotId': 'Q57NN5',
#   'position': '235',
#   'description': 'N5-methylglutamine',
#   'evidence': '1',
#   'pubmedId': '15781495',
#   'journal': 'Nucleic Acids Res.',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '2',
#   'description': 'N-acetylserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '2',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '4',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '5',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '22',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '16141072',
#   'journal': 'Science',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '39',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '196',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '359',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ythdf2',
#   'name': 'YTH domain-containing family protein 2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q91YT7',
#   'position': '394',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Ubl3',
#   'name': 'Ubiquitin-like protein 3',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q9Z2M6',
#   'position': '114',
#   'description': 'Cysteine methyl ester',
#   'evidence': '3',
#   'pubmedId': '15489334',
#   'journal': 'Genome Res.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Etf1',
#   'name': 'Eukaryotic peptide chain release factor subunit 1',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q8BWY3',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '1',
#   'pubmedId': '16141072',
#   'journal': 'Science',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'Etf1',
#   'name': 'Eukaryotic peptide chain release factor subunit 1',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q8BWY3',
#   'position': '63',
#   'description': '4-hydroxylysine',
#   'evidence': '3',
#   'pubmedId': '14636559',
#   'journal': 'Cell',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'Etf1',
#   'name': 'Eukaryotic peptide chain release factor subunit 1',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q8BWY3',
#   'position': '185',
#   'description': 'N5-methylglutamine',
#   'evidence': '5',
#   'pubmedId': '20606008',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'Etf1',
#   'name': 'Eukaryotic peptide chain release factor subunit 1',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q8BWY3',
#   'position': '347',
#   'description': 'Phosphothreonine',
#   'evidence': '1',
#   'pubmedId': '16141072',
#   'journal': 'Science',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'iacP',
#   'name': 'Probable acyl carrier protein IacP',
#   'organism': 'Salmonella typhi',
#   'uniprotId': 'Q8Z495',
#   'position': '38',
#   'description': "O-(pantetheine 4'-phosphoryl)serine",
#   'evidence': '2',
#   'pubmedId': '11677608',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2001'},
#  {'gene': None,
#   'name': 'Tachykinin-related peptide 2',
#   'organism': 'Nezara viridula',
#   'uniprotId': 'P86576',
#   'position': '10',
#   'description': 'Arginine amide',
#   'evidence': '1',
#   'pubmedId': '19084564',
#   'journal': 'Peptides',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '12',
#   'pubmedId': '19690332',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '142',
#   'description': 'Phosphoserine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '142',
#   'description': 'Phosphoserine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '20460684',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '142',
#   'description': 'Phosphoserine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '142',
#   'description': 'Phosphoserine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '21269460',
#   'journal': 'BMC Syst. Biol.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '142',
#   'description': 'Phosphoserine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '172',
#   'description': 'Phosphotyrosine',
#   'evidence': '13',
#   'pubmedId': '20460684',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '176',
#   'description': 'Phosphothreonine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '176',
#   'description': 'Phosphothreonine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '20460684',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '176',
#   'description': 'Phosphothreonine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '176',
#   'description': 'Phosphothreonine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '21269460',
#   'journal': 'BMC Syst. Biol.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '176',
#   'description': 'Phosphothreonine',
#   'evidence': '11 13 14 15 16',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '200',
#   'description': 'Phosphoserine',
#   'evidence': '14 16',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '200',
#   'description': 'Phosphoserine',
#   'evidence': '14 16',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '244',
#   'description': 'Phosphoserine',
#   'evidence': '15',
#   'pubmedId': '21269460',
#   'journal': 'BMC Syst. Biol.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'DPF2',
#   'name': 'Zinc finger protein ubi-d4',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q92785',
#   'position': '280',
#   'description': 'Phosphoserine',
#   'evidence': '16',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'AP3B1',
#   'name': 'AP-3 complex subunit beta-1',
#   'organism': 'Bos taurus',
#   'uniprotId': 'Q32PG1',
#   'position': '276',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'AP3B1',
#   'name': 'AP-3 complex subunit beta-1',
#   'organism': 'Bos taurus',
#   'uniprotId': 'Q32PG1',
#   'position': '609',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'AP3B1',
#   'name': 'AP-3 complex subunit beta-1',
#   'organism': 'Bos taurus',
#   'uniprotId': 'Q32PG1',
#   'position': '742',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'GNG3',
#   'name': 'Guanine nucleotide-binding protein G(I)/G(S)/G(O) subunit gamma-3',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63215',
#   'position': '5',
#   'description': 'Phosphothreonine',
#   'evidence': '2',
#   'pubmedId': '10819326',
#   'journal': 'DNA Res.',
#   'title': None,
#   'date': '2000'},
#  {'gene': 'GNG3',
#   'name': 'Guanine nucleotide-binding protein G(I)/G(S)/G(O) subunit gamma-3',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63215',
#   'position': '9',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '10819326',
#   'journal': 'DNA Res.',
#   'title': None,
#   'date': '2000'},
#  {'gene': 'GNG3',
#   'name': 'Guanine nucleotide-binding protein G(I)/G(S)/G(O) subunit gamma-3',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63215',
#   'position': '10',
#   'description': 'Phosphothreonine',
#   'evidence': '2',
#   'pubmedId': '10819326',
#   'journal': 'DNA Res.',
#   'title': None,
#   'date': '2000'},
#  {'gene': 'GNG3',
#   'name': 'Guanine nucleotide-binding protein G(I)/G(S)/G(O) subunit gamma-3',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63215',
#   'position': '12',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '10819326',
#   'journal': 'DNA Res.',
#   'title': None,
#   'date': '2000'},
#  {'gene': 'GNG3',
#   'name': 'Guanine nucleotide-binding protein G(I)/G(S)/G(O) subunit gamma-3',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P63215',
#   'position': '72',
#   'description': 'Cysteine methyl ester',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': None,
#   'name': 'Conotoxin tx5b',
#   'organism': 'Conus textile',
#   'uniprotId': 'P86258',
#   'position': '14',
#   'description': 'Isoleucine amide; partial',
#   'evidence': '2',
#   'pubmedId': '22709442',
#   'journal': 'J. Proteome Res.',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'SLC2A3',
#   'name': 'Solute carrier family 2, facilitated glucose transporter member 3',
#   'organism': 'Ovis aries',
#   'uniprotId': 'P47843',
#   'position': '232',
#   'description': 'Phosphothreonine',
#   'evidence': '2',
#   'pubmedId': '9250701',
#   'journal': 'Placenta',
#   'title': None,
#   'date': '1997'},
#  {'gene': 'Map3k10',
#   'name': 'Mitogen-activated protein kinase kinase kinase 10',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q66L42',
#   'position': '258',
#   'description': 'Phosphothreonine; by autocatalysis',
#   'evidence': '1',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map3k10',
#   'name': 'Mitogen-activated protein kinase kinase kinase 10',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q66L42',
#   'position': '262',
#   'description': 'Phosphoserine; by autocatalysis and MAP4K1',
#   'evidence': '1',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ADH1B',
#   'name': 'All-trans-retinol dehydrogenase [NAD(+)] ADH1B',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P00325',
#   'position': '2',
#   'description': 'N-acetylserine',
#   'evidence': '14',
#   'pubmedId': '6391920',
#   'journal': 'Eur. J. Biochem.',
#   'title': None,
#   'date': '1984'},
#  {'gene': 'ADH1B',
#   'name': 'All-trans-retinol dehydrogenase [NAD(+)] ADH1B',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P00325',
#   'position': '23',
#   'description': 'Phosphoserine',
#   'evidence': '23',
#   'pubmedId': '8201622',
#   'journal': 'J. Mol. Biol.',
#   'title': None,
#   'date': '1994'},
#  {'gene': 'ADH1B',
#   'name': 'All-trans-retinol dehydrogenase [NAD(+)] ADH1B',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'P00325',
#   'position': '35',
#   'description': 'Phosphotyrosine',
#   'evidence': '23',
#   'pubmedId': '8201622',
#   'journal': 'J. Mol. Biol.',
#   'title': None,
#   'date': '1994'},
#  {'gene': 'cheB',
#   'name': 'Protein-glutamate methylesterase/protein-glutamine glutaminase',
#   'organism': 'Bordetella pertussis (strain Tohama I / ATCC BAA-589 / NCTC 13251)',
#   'uniprotId': 'Q7VZ94',
#   'position': '56',
#   'description': '4-aspartylphosphate',
#   'evidence': '1',
#   'pubmedId': '12910271',
#   'journal': 'Nat. Genet.',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'speD',
#   'name': 'S-adenosylmethionine decarboxylase proenzyme',
#   'organism': 'Stenotrophomonas maltophilia (strain R551-3)',
#   'uniprotId': 'B4SLE4',
#   'position': '113',
#   'description': 'Pyruvic acid (Ser); by autocatalysis',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': None,
#   'name': 'Thiocillin GE2270',
#   'organism': 'Planobispora rosea',
#   'uniprotId': 'Q7M0J8',
#   'position': '3',
#   'description': 'N4-methylasparagine',
#   'evidence': '5',
#   'pubmedId': '1880060',
#   'journal': 'J. Antibiot.',
#   'title': None,
#   'date': '1991'},
#  {'gene': None,
#   'name': 'Thiocillin GE2270',
#   'organism': 'Planobispora rosea',
#   'uniprotId': 'Q7M0J8',
#   'position': '8',
#   'description': '3-hydroxyphenylalanine',
#   'evidence': '1',
#   'pubmedId': '1908853',
#   'journal': 'J. Antibiot.',
#   'title': None,
#   'date': '1991'},
#  {'gene': None,
#   'name': 'Thiocillin GE2270',
#   'organism': 'Planobispora rosea',
#   'uniprotId': 'Q7M0J8',
#   'position': '14',
#   'description': 'Proline amide',
#   'evidence': '2',
#   'pubmedId': '7647369',
#   'journal': 'Rapid Commun. Mass Spectrom.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Eif4e',
#   'name': 'Eukaryotic translation initiation factor 4E',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'P63074',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '1',
#   'pubmedId': '8558852',
#   'journal': 'Lab. Invest.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Eif4e',
#   'name': 'Eukaryotic translation initiation factor 4E',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'P63074',
#   'position': '22',
#   'description': 'Phosphothreonine',
#   'evidence': '1',
#   'pubmedId': '8558852',
#   'journal': 'Lab. Invest.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Eif4e',
#   'name': 'Eukaryotic translation initiation factor 4E',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'P63074',
#   'position': '209',
#   'description': 'Phosphoserine; by PKC and MKNK2',
#   'evidence': '1',
#   'pubmedId': '8558852',
#   'journal': 'Lab. Invest.',
#   'title': None,
#   'date': '1995'},
#  {'gene': None,
#   'name': 'Pyridoxal phosphate homeostasis protein',
#   'organism': 'Caenorhabditis elegans',
#   'uniprotId': 'P52057',
#   'position': '37',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': '9851916',
#   'journal': 'Science',
#   'title': None,
#   'date': '1998'},
#  {'gene': 'cth-2',
#   'name': 'Putative cystathionine gamma-lyase 2',
#   'organism': 'Caenorhabditis elegans',
#   'uniprotId': 'P55216',
#   'position': '203',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': '9851916',
#   'journal': 'Science',
#   'title': None,
#   'date': '1998'},
#  {'gene': 'gacA',
#   'name': 'Response regulator GacA',
#   'organism': 'Pseudomonas viridiflava',
#   'uniprotId': 'P95582',
#   'position': '54',
#   'description': '4-aspartylphosphate',
#   'evidence': '1',
#   'pubmedId': '8742358',
#   'journal': 'Can. J. Microbiol.',
#   'title': None,
#   'date': '1996'},
#  {'gene': 'rplB',
#   'name': '50S ribosomal protein L2',
#   'organism': 'Escherichia coli O7:K1 (strain IAI39 / ExPEC)',
#   'uniprotId': 'B7NLN6',
#   'position': '242',
#   'description': 'N6-acetyllysine',
#   'evidence': '1',
#   'pubmedId': '19165319',
#   'journal': 'PLoS Genet.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'TIP41',
#   'name': 'Type 2A phosphatase activator TIP41',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'Q12199',
#   'position': '55',
#   'description': 'Phosphothreonine',
#   'evidence': '5 6',
#   'pubmedId': '14504216',
#   'journal': 'Genetics',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'TIP41',
#   'name': 'Type 2A phosphatase activator TIP41',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'Q12199',
#   'position': '55',
#   'description': 'Phosphothreonine',
#   'evidence': '5 6',
#   'pubmedId': '14562095',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2003'},
#  {'gene': None,
#   'name': 'Mini-chromosome maintenance complex-binding protein',
#   'organism': 'Drosophila melanogaster',
#   'uniprotId': 'Q9VM60',
#   'position': '147',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '12537572',
#   'journal': 'Genome Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': None,
#   'name': 'Mini-chromosome maintenance complex-binding protein',
#   'organism': 'Drosophila melanogaster',
#   'uniprotId': 'Q9VM60',
#   'position': '150',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '12537572',
#   'journal': 'Genome Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'hemC',
#   'name': 'Porphobilinogen deaminase',
#   'organism': 'Shigella flexneri',
#   'uniprotId': 'Q83PH4',
#   'position': '242',
#   'description': 'S-(dipyrrolylmethanemethyl)cysteine',
#   'evidence': '1',
#   'pubmedId': '12384590',
#   'journal': 'Nucleic Acids Res.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '51',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '10359087',
#   'journal': 'FEBS Lett.',
#   'title': None,
#   'date': '1999'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '194',
#   'description': 'Phosphothreonine',
#   'evidence': '10',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '250',
#   'description': 'Phosphoserine',
#   'evidence': '10',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '301',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '10359087',
#   'journal': 'FEBS Lett.',
#   'title': None,
#   'date': '1999'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '18669648',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2008'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '19608861',
#   'journal': 'Science',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '306',
#   'description': 'Phosphoserine',
#   'evidence': '9 10 12 13 14 15',
#   'pubmedId': '23186163',
#   'journal': 'J. Proteome Res.',
#   'title': None,
#   'date': '2013'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '412',
#   'description': 'Phosphoserine',
#   'evidence': '10 14 15',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '412',
#   'description': 'Phosphoserine',
#   'evidence': '10 14 15',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '412',
#   'description': 'Phosphoserine',
#   'evidence': '10 14 15',
#   'pubmedId': '23186163',
#   'journal': 'J. Proteome Res.',
#   'title': None,
#   'date': '2013'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '607',
#   'description': 'N6-acetyllysine',
#   'evidence': '11',
#   'pubmedId': '19690332',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '665',
#   'description': 'Phosphoserine',
#   'evidence': '13 14',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '665',
#   'description': 'Phosphoserine',
#   'evidence': '13 14',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '784',
#   'description': 'Phosphoserine',
#   'evidence': '10 12 13',
#   'pubmedId': '19413330',
#   'journal': 'Anal. Chem.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '784',
#   'description': 'Phosphoserine',
#   'evidence': '10 12 13',
#   'pubmedId': '19608861',
#   'journal': 'Science',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'ZNF148',
#   'name': 'Zinc finger protein 148',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q9UQR1',
#   'position': '784',
#   'description': 'Phosphoserine',
#   'evidence': '10 12 13',
#   'pubmedId': '20068231',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2010'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '96',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '96',
#   'description': 'N6-succinyllysine; alternate',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '219',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '219',
#   'description': 'N6-succinyllysine; alternate',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '223',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'DHRS2',
#   'name': 'Dehydrogenase/reductase SDR family member 2, mitochondrial',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q13268',
#   'position': '237',
#   'description': 'N6-succinyllysine',
#   'evidence': '2',
#   'pubmedId': '11997086',
#   'journal': 'Biochim. Biophys. Acta',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'RAB6A',
#   'name': 'Ras-related protein Rab-6A',
#   'organism': 'Gallus gallus',
#   'uniprotId': 'Q1KME6',
#   'position': '2',
#   'description': 'N-acetylserine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'RAB6A',
#   'name': 'Ras-related protein Rab-6A',
#   'organism': 'Gallus gallus',
#   'uniprotId': 'Q1KME6',
#   'position': '208',
#   'description': 'Cysteine methyl ester',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'glyA',
#   'name': 'Serine hydroxymethyltransferase',
#   'organism': 'Hyperthermus butylicus (strain DSM 5456 / JCM 9403 / PLM1-5)',
#   'uniprotId': 'A2BM73',
#   'position': '236',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': '17350933',
#   'journal': 'Archaea',
#   'title': None,
#   'date': '2007'},
#  {'gene': 'bioF',
#   'name': 'Putative 8-amino-7-oxononanoate synthase',
#   'organism': 'Acetivibrio thermocellus (strain ATCC 27405 / DSM 1237 / JCM 9322 / NBRC 103400 / NCIMB 10682 / NRRL B-4536 / VPI 7372)',
#   'uniprotId': 'A3DBD5',
#   'position': '235',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '341',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '527',
#   'description': 'Phosphothreonine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '933',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '934',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '960',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1183',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1186',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1260',
#   'description': 'Phosphoserine',
#   'evidence': '16 19',
#   'pubmedId': '33268592',
#   'journal': 'JCI Insight',
#   'title': None,
#   'date': '2020'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1271',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1275',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1277',
#   'description': 'Phosphothreonine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1293',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1391',
#   'description': 'Phosphoserine',
#   'evidence': '16 19',
#   'pubmedId': '33268592',
#   'journal': 'JCI Insight',
#   'title': None,
#   'date': '2020'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1395',
#   'description': 'Phosphoserine',
#   'evidence': '16 19',
#   'pubmedId': '33268592',
#   'journal': 'JCI Insight',
#   'title': None,
#   'date': '2020'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1422',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1516',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1518',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1521',
#   'description': 'Phosphothreonine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1614',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1649',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1659',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1815',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '19468303',
#   'journal': 'PLoS Biol.',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '1915',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2205',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2267',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2285',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2301',
#   'description': 'Phosphothreonine',
#   'evidence': '3',
#   'pubmedId': '12147674',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Map1b',
#   'name': 'Microtubule-associated protein 1B',
#   'organism': 'Mus musculus',
#   'uniprotId': 'P14873',
#   'position': '2460',
#   'description': 'S-nitrosocysteine',
#   'evidence': '8',
#   'pubmedId': '17114649',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2007'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '7',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '19',
#   'pubmedId': '15166219',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '8',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '19',
#   'pubmedId': '15166219',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '11',
#   'description': 'Phosphoserine',
#   'evidence': '16 17',
#   'pubmedId': '15186774',
#   'journal': 'Cell',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '11',
#   'description': 'Phosphoserine',
#   'evidence': '16 17',
#   'pubmedId': '14752010',
#   'journal': 'Genes Dev.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '12',
#   'description': 'N6-acetyllysine',
#   'evidence': '4 12',
#   'pubmedId': '24374639',
#   'journal': 'G3 (Bethesda)',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '12',
#   'description': 'N6-acetyllysine',
#   'evidence': '4 12',
#   'pubmedId': '12152067',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '17',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '4 12 19 20',
#   'pubmedId': '24374639',
#   'journal': 'G3 (Bethesda)',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '17',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '4 12 19 20',
#   'pubmedId': '12152067',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '17',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '4 12 19 20',
#   'pubmedId': '15166219',
#   'journal': 'J. Biol. Chem.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '17',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '4 12 19 20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '18',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '22',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '22',
#   'description': 'N6-butyryllysine; alternate',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '23',
#   'description': 'N6-acetyllysine; alternate',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '23',
#   'description': 'N6-methyllysine; alternate',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '35',
#   'description': 'N6-succinyllysine',
#   'evidence': '21',
#   'pubmedId': '15652479',
#   'journal': 'Cell',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '38',
#   'description': 'N6,N6-dimethyllysine',
#   'evidence': '20',
#   'pubmedId': '15280549',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'HTB1',
#   'name': 'Histone H2B.1',
#   'organism': 'Saccharomyces cerevisiae (strain ATCC 204508 / S288c)',
#   'uniprotId': 'P02293',
#   'position': '47',
#   'description': 'N6-succinyllysine',
#   'evidence': '21',
#   'pubmedId': '15652479',
#   'journal': 'Cell',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'astC',
#   'name': 'Succinylornithine transaminase',
#   'organism': 'Salmonella paratyphi A (strain AKU_12601)',
#   'uniprotId': 'B5BA72',
#   'position': '252',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': '19159446',
#   'journal': 'BMC Genomics',
#   'title': None,
#   'date': '2009'},
#  {'gene': 'TPP2',
#   'name': 'Tripeptidyl-peptidase 2',
# ...
#   'description': 'Phosphoserine',
#   'evidence': '4',
#   'pubmedId': '12537569',
#   'journal': 'Genome Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'NKAIN',
#   'name': 'Sodium/potassium-transporting ATPase subunit beta-1-interacting protein',
#   'organism': 'Drosophila melanogaster',
#   'uniprotId': 'A6MHQ4',
#   'position': '398',
#   'description': 'Phosphoserine',
#   'evidence': '4',
#   'pubmedId': '12537569',
#   'journal': 'Genome Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'NKAIN',
#   'name': 'Sodium/potassium-transporting ATPase subunit beta-1-interacting protein',
#   'organism': 'Drosophila melanogaster',
#   'uniprotId': 'A6MHQ4',
#   'position': '399',
#   'description': 'Phosphoserine',
#   'evidence': '4',
#   'pubmedId': '12537569',
#   'journal': 'Genome Biol.',
#   'title': None,
#   'date': '2002'},
#  {'gene': 'Hk2',
#   'name': 'Hexokinase-2',
#   'organism': 'Mus musculus',
#   'uniprotId': 'O08528',
#   'position': '1',
#   'description': 'N-acetylmethionine',
#   'evidence': '3',
#   'pubmedId': '18350175',
#   'journal': 'PLoS ONE',
#   'title': None,
#   'date': '2008'},
#  {'gene': 'PPIA',
#   'name': 'Peptidyl-prolyl cis-trans isomerase A',
#   'organism': 'Papio anubis',
#   'uniprotId': 'P62941',
#   'position': '133',
#   'description': 'N6-acetyllysine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'THI1',
#   'name': 'Thiamine thiazole synthase, chloroplastic',
#   'organism': 'Arabidopsis thaliana',
#   'uniprotId': 'Q38814',
#   'position': '216',
#   'description': '2,3-didehydroalanine (Cys)',
#   'evidence': '9',
#   'pubmedId': '15897230',
#   'journal': 'J. Exp. Bot.',
#   'title': None,
#   'date': '2005'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '13 23 27 28',
#   'pubmedId': '16964243',
#   'journal': 'Nat. Biotechnol.',
#   'title': None,
#   'date': '2006'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '13 23 27 28',
#   'pubmedId': '22814378',
#   'journal': 'Proc. Natl. Acad. Sci. U.S.A.',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '13 23 27 28',
#   'pubmedId': '11691992',
#   'journal': 'Science',
#   'title': None,
#   'date': '2001'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '13 23 27 28',
#   'pubmedId': '12718882',
#   'journal': 'Mol. Cell',
#   'title': None,
#   'date': '2003'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '20',
#   'description': 'Phosphoserine; by PKG',
#   'evidence': '5',
#   'pubmedId': '16554811',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2006'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '80',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '22223895',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '80',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '23186163',
#   'journal': 'J. Proteome Res.',
#   'title': None,
#   'date': '2013'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '80',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '24275569',
#   'journal': 'J. Proteomics',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '80',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '24129315',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '82',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '22223895',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '82',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '23186163',
#   'journal': 'J. Proteome Res.',
#   'title': None,
#   'date': '2013'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '82',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '24275569',
#   'journal': 'J. Proteomics',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '82',
#   'description': 'Phosphoserine',
#   'evidence': '22 24 25 26 29',
#   'pubmedId': '24129315',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2014'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '463',
#   'description': 'Phosphoserine',
#   'evidence': '20 21 22',
#   'pubmedId': '21269460',
#   'journal': 'BMC Syst. Biol.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '463',
#   'description': 'Phosphoserine',
#   'evidence': '20 21 22',
#   'pubmedId': '21406692',
#   'journal': 'Sci. Signal.',
#   'title': None,
#   'date': '2011'},
#  {'gene': 'SF1',
#   'name': 'Splicing factor 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'Q15637',
#   'position': '463',
#   'description': 'Phosphoserine',
#   'evidence': '20 21 22',
#   'pubmedId': '22223895',
#   'journal': 'Mol. Cell. Proteomics',
#   'title': None,
#   'date': '2012'},
#  {'gene': 'dnaK',
#   'name': 'Chaperone protein DnaK',
#   'organism': 'Vibrio vulnificus (strain CMCP6)',
#   'uniprotId': 'Q8DF66',
#   'position': '198',
#   'description': 'Phosphothreonine; by autocatalysis',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'tco89',
#   'name': 'Target of rapamycin complex 1 subunit tco89',
#   'organism': 'Schizosaccharomyces pombe (strain 972 / ATCC 24843)',
#   'uniprotId': 'O74428',
#   'position': '70',
#   'description': 'Phosphoserine',
#   'evidence': '3',
#   'pubmedId': '18076573',
#   'journal': 'Genes Cells',
#   'title': None,
#   'date': '2007'},
#  {'gene': 'hemL',
#   'name': 'Glutamate-1-semialdehyde 2,1-aminomutase',
#   'organism': 'Shewanella baltica (strain OS185)',
#   'uniprotId': 'A6WKL6',
#   'position': '265',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '2',
#   'description': 'N-acetylthreonine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '29',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '30',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '34',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '44',
#   'description': 'Phosphothreonine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '92',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '93',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '461',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': 'Ralbp1',
#   'name': 'RalA-binding protein 1',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'Q62796',
#   'position': '637',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '7623849',
#   'journal': 'Mol. Cell. Biol.',
#   'title': None,
#   'date': '1995'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '2',
#   'description': 'Phosphoserine; by host',
#   'evidence': '3',
#   'pubmedId': '16903222',
#   'journal': 'Curr. Top. Microbiol. Immunol.',
#   'title': None,
#   'date': '2006'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '13',
#   'description': 'Omega-N-methylated arginine; by host',
#   'evidence': '2',
#   'pubmedId': '16402678',
#   'journal': 'Acta Virol.',
#   'title': None,
#   'date': '2005'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '71',
#   'description': 'N6-acetyllysine; by host',
#   'evidence': '2',
#   'pubmedId': '16402678',
#   'journal': 'Acta Virol.',
#   'title': None,
#   'date': '2005'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '122',
#   'description': 'Phosphoserine; by host',
#   'evidence': '3',
#   'pubmedId': '16903222',
#   'journal': 'Curr. Top. Microbiol. Immunol.',
#   'title': None,
#   'date': '2006'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '176',
#   'description': 'Phosphoserine; by host',
#   'evidence': '3',
#   'pubmedId': '16903222',
#   'journal': 'Curr. Top. Microbiol. Immunol.',
#   'title': None,
#   'date': '2006'},
#  {'gene': None,
#   'name': 'Large delta antigen',
#   'organism': 'Hepatitis delta virus genotype III (isolate VnzD8375)',
#   'uniprotId': 'P0C6M7',
#   'position': '211',
#   'description': 'Cysteine methyl ester; by host',
#   'evidence': '3',
#   'pubmedId': '16903222',
#   'journal': 'Curr. Top. Microbiol. Immunol.',
#   'title': None,
#   'date': '2006'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '549',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '15057822',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '558',
#   'description': 'Phosphoserine; by PKA',
#   'evidence': '1',
#   'pubmedId': '15057822',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '599',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '15057822',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '605',
#   'description': 'Phosphothreonine; by PKA and CaMK2',
#   'evidence': '1',
#   'pubmedId': '15057822',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '617',
#   'description': 'Phosphotyrosine',
#   'evidence': '2',
#   'pubmedId': '11673475',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2001'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '724',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '11673475',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2001'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '776',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '15057822',
#   'journal': 'Nature',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Synpo2',
#   'name': 'Synaptopodin-2',
#   'organism': 'Rattus norvegicus',
#   'uniprotId': 'D4A702',
#   'position': '1055',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '11673475',
#   'journal': 'J. Cell Biol.',
#   'title': None,
#   'date': '2001'},
#  {'gene': 'KCNH2',
#   'name': 'Potassium voltage-gated channel subfamily H member 2',
#   'organism': 'Oryctolagus cuniculus',
#   'uniprotId': 'Q8WNY2',
#   'position': '353',
#   'description': 'Phosphoserine',
#   'evidence': '2',
#   'pubmedId': '9012748',
#   'journal': 'Circ. Res.',
#   'title': None,
#   'date': '1997'},
#  {'gene': 'rocD',
#   'name': 'Ornithine aminotransferase',
#   'organism': 'Brevibacillus brevis (strain 47 / JCM 6285 / NBRC 100599)',
#   'uniprotId': 'C0ZBR4',
#   'position': '255',
#   'description': 'N6-(pyridoxal phosphate)lysine',
#   'evidence': '1',
#   'pubmedId': None,
#   'journal': None,
#   'title': None,
#   'date': None},
#  {'gene': 'Snrpa',
#   'name': 'U1 small nuclear ribonucleoprotein A',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q62189',
#   'position': '66',
#   'description': 'N6-acetyllysine',
#   'evidence': '2',
#   'pubmedId': '15489334',
#   'journal': 'Genome Res.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'Snrpa',
#   'name': 'U1 small nuclear ribonucleoprotein A',
#   'organism': 'Mus musculus',
#   'uniprotId': 'Q62189',
#   'position': '157',
#   'description': 'Omega-N-methylarginine',
#   'evidence': '2',
#   'pubmedId': '15489334',
#   'journal': 'Genome Res.',
#   'title': None,
#   'date': '2004'},
#  {'gene': 'TMCC1',
#   'name': 'Transmembrane and coiled-coil domains protein 1',
#   'organism': 'Homo sapiens',
#   'uniprotId': 'O94876',
#   'position': '382',
#   'description': 'Phosphoserine',
#   'evidence': '13 14 16 17',
#   'pubmedId': '30220460',
#   'journal': 'Cell',
#   'title': None,
#   'date': '2018'},
#  {'gene': 'ADH5',
#   'name': 'Alcohol dehydrogenase class-3',
#   'organism': 'Oryctolagus cuniculus',
#   'uniprotId': 'O19053',
#   'position': '2',
#   'description': 'N-acetylalanine',
#   'evidence': '1',
#   'pubmedId': '9492289',
#   'journal': 'Eur. J. Biochem.',
#   'title': None,
#   'date': '1998'},
#  {'gene': 'ADH5',
#   'name': 'Alcohol dehydrogenase class-3',
#   'organism': 'Oryctolagus cuniculus',
#   'uniprotId': 'O19053',
#   'position': '247',
#   'description': 'Phosphoserine',
#   'evidence': '1',
#   'pubmedId': '9492289',
#   'journal': 'Eur. J. Biochem.',
#   'title': None,
#   'date': '1998'},
#  ...]

# %%
with open('data/output/REF_DATA.json', 'w') as f:
     json.dump(REF_DATA,f)

#with open('output/REF_DATA.json', 'r') as f:
#     PTM_DATA = json.load(f)

# %% [markdown]
# - How many PTM data are found? What is the PTM data %?

# %%
df_modres_ref = pd.DataFrame(REF_DATA)

# %%
df_modres_ref.head(10)
# Out:
#     gene                  name            organism uniprotId position  \
# 0   scly  Selenocysteine lyase  Xenopus tropicalis    Q5U4Q9      239
# 1  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        1
# 2  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        1
# 3  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        1
# 4  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
# 5  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
# 6  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
# 7  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
# 8  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
# 9  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        2
#
#                                          description                 evidence  \
# 0                     N6-(pyridoxal phosphate)lysine                        1
# 1                                 N-acetylmethionine                 17 25 26
# 2                                 N-acetylmethionine                 17 25 26
# 3                                 N-acetylmethionine                 17 25 26
# 4  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
# 5  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
# 6  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
# 7  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
# 8  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
# 9  N-acetylglutamate; in Actin, cytoplasmic 2, N-...  14 15 18 19 24 25 26 27
#
#    pubmedId                        journal title  date
# 0      None                           None  None  None
# 1  25944712                     Proteomics  None  2015
# 2  16773128            Eur. J. Hum. Genet.  None  2006
# 3  18804074             J. Genet. Genomics  None  2008
# 4  22223895          Mol. Cell. Proteomics  None  2012
# 5  22814378  Proc. Natl. Acad. Sci. U.S.A.  None  2012
# 6  26228148                        Science  None  2015
# 7  30028079                        FEBS J.  None  2018
# 8  14684684                 J. Med. Genet.  None  2003
# 9  16773128            Eur. J. Hum. Genet.  None  2006

# %% [markdown]
# #### Create PTM Identifier from description:
# WE want to create identifier from description column to match identifier from PTM vocab file

# %%
df_modres_ref['Identifier'] = df_modres_ref['description']\
        .apply(lambda x: x.split(';')[0].lower() if ";" in x else x.lower())

# %%
with open('data/ptm/idf2accession.json', 'r') as f:
    idf2accession = json.load(f)

df_modres_ref['ptm_accession'] = df_modres_ref['Identifier']\
        .apply(lambda x: idf2accession[x] if x in idf2accession else None)

# %%
df_modres_ref.head(2)
# Out:
#     gene                  name            organism uniprotId position  \
# 0   scly  Selenocysteine lyase  Xenopus tropicalis    Q5U4Q9      239
# 1  ACTG1  Actin, cytoplasmic 2        Homo sapiens    P63261        1
#
#                       description  evidence  pubmedId     journal title  date  \
# 0  N6-(pyridoxal phosphate)lysine         1      None        None  None  None
# 1              N-acetylmethionine  17 25 26  25944712  Proteomics  None  2015
#
#                        Identifier ptm_accession
# 0  n6-(pyridoxal phosphate)lysine          None
# 1              n-acetylmethionine      PTM-0205

# %%
df_modres_ref = df_modres_ref.dropna(subset=['ptm_accession'])
df_modres_ref = df_modres_ref.dropna(subset=['pubmedId'])

# %%
df_modres_ref.columns
# Out:
# Index(['gene', 'name', 'organism', 'uniprotId', 'position', 'description',
#        'evidence', 'pubmedId', 'journal', 'title', 'date', 'Identifier',
#        'ptm_accession'],
#       dtype='object')

# %%
df_modres_ref.shape
# Out:
# (161607, 13)

# %%
df_modres_ref['mod_res_id'] = df_modres_ref['uniprotId'] \
        + "_" + df_modres_ref['ptm_accession'] + "_" + df_modres_ref['position'].astype(str)

# %%
df_modres_ref.head(20)
# Out:
#       gene                                    name  \
# 1    ACTG1                    Actin, cytoplasmic 2
# 2    ACTG1                    Actin, cytoplasmic 2
# 3    ACTG1                    Actin, cytoplasmic 2
# 4    ACTG1                    Actin, cytoplasmic 2
# 5    ACTG1                    Actin, cytoplasmic 2
# 6    ACTG1                    Actin, cytoplasmic 2
# 7    ACTG1                    Actin, cytoplasmic 2
# 8    ACTG1                    Actin, cytoplasmic 2
# 9    ACTG1                    Actin, cytoplasmic 2
# 10   ACTG1                    Actin, cytoplasmic 2
# 11   ACTG1                    Actin, cytoplasmic 2
# 14   ACTG1                    Actin, cytoplasmic 2
# 15   ACTG1                    Actin, cytoplasmic 2
# 16   ACTG1                    Actin, cytoplasmic 2
# 17    prfA          Peptide chain release factor 1
# 18  Ythdf2  YTH domain-containing family protein 2
# 19  Ythdf2  YTH domain-containing family protein 2
# 20  Ythdf2  YTH domain-containing family protein 2
# 21  Ythdf2  YTH domain-containing family protein 2
# 22  Ythdf2  YTH domain-containing family protein 2
#
#                                    organism uniprotId position  \
# 1                              Homo sapiens    P63261        1
# 2                              Homo sapiens    P63261        1
# 3                              Homo sapiens    P63261        1
# 4                              Homo sapiens    P63261        2
# 5                              Homo sapiens    P63261        2
# 6                              Homo sapiens    P63261        2
# 7                              Homo sapiens    P63261        2
# 8                              Homo sapiens    P63261        2
# 9                              Homo sapiens    P63261        2
# 10                             Homo sapiens    P63261        2
# 11                             Homo sapiens    P63261        2
# 14                             Homo sapiens    P63261       73
# 15                             Homo sapiens    P63261       73
# 16                             Homo sapiens    P63261       84
# 17  Salmonella choleraesuis (strain SC-B67)    Q57NN5      235
# 18                             Mus musculus    Q91YT7        2
# 19                             Mus musculus    Q91YT7        2
# 20                             Mus musculus    Q91YT7        4
# 21                             Mus musculus    Q91YT7        5
# 22                             Mus musculus    Q91YT7       22
#
#                                           description  \
# 1                                  N-acetylmethionine
# 2                                  N-acetylmethionine
# 3                                  N-acetylmethionine
# 4   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 5   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 6   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 7   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 8   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 9   N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 10  N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 11  N-acetylglutamate; in Actin, cytoplasmic 2, N-...
# 14                               Tele-methylhistidine
# 15                               Tele-methylhistidine
# 16                                    N6-methyllysine
# 17                                 N5-methylglutamine
# 18                                     N-acetylserine
# 19                                      Phosphoserine
# 20                                      Phosphoserine
# 21                                      Phosphoserine
# 22                                      Phosphoserine
#
#                    evidence  pubmedId                        journal title  \
# 1                  17 25 26  25944712                     Proteomics  None
# 2                  17 25 26  16773128            Eur. J. Hum. Genet.  None
# 3                  17 25 26  18804074             J. Genet. Genomics  None
# 4   14 15 18 19 24 25 26 27  22223895          Mol. Cell. Proteomics  None
# 5   14 15 18 19 24 25 26 27  22814378  Proc. Natl. Acad. Sci. U.S.A.  None
# 6   14 15 18 19 24 25 26 27  26228148                        Science  None
# 7   14 15 18 19 24 25 26 27  30028079                        FEBS J.  None
# 8   14 15 18 19 24 25 26 27  14684684                 J. Med. Genet.  None
# 9   14 15 18 19 24 25 26 27  16773128            Eur. J. Hum. Genet.  None
# 10  14 15 18 19 24 25 26 27  18804074             J. Genet. Genomics  None
# 11  14 15 18 19 24 25 26 27  19477959               Hum. Mol. Genet.  None
# 14                    16 19  23673617                   Nat. Commun.  None
# 15                    16 19  30028079                        FEBS J.  None
# 16                       11  14654843                         Nature  None
# 17                        1  15781495             Nucleic Acids Res.  None
# 18                        2  19468303                     PLoS Biol.  None
# 19                        2  19468303                     PLoS Biol.  None
# 20                        2  19468303                     PLoS Biol.  None
# 21                        2  19468303                     PLoS Biol.  None
# 22                        1  16141072                        Science  None
#
#     date            Identifier ptm_accession           mod_res_id
# 1   2015    n-acetylmethionine      PTM-0205    P63261_PTM-0205_1
# 2   2006    n-acetylmethionine      PTM-0205    P63261_PTM-0205_1
# 3   2008    n-acetylmethionine      PTM-0205    P63261_PTM-0205_1
# 4   2012     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 5   2012     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 6   2015     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 7   2018     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 8   2003     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 9   2006     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 10  2008     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 11  2009     n-acetylglutamate      PTM-0202    P63261_PTM-0202_2
# 14  2013  tele-methylhistidine      PTM-0290   P63261_PTM-0290_73
# 15  2018  tele-methylhistidine      PTM-0290   P63261_PTM-0290_73
# 16  2003       n6-methyllysine      PTM-0194   P63261_PTM-0194_84
# 17  2005    n5-methylglutamine      PTM-0185  Q57NN5_PTM-0185_235
# 18  2009        n-acetylserine      PTM-0207    Q91YT7_PTM-0207_2
# 19  2009         phosphoserine      PTM-0253    Q91YT7_PTM-0253_2
# 20  2009         phosphoserine      PTM-0253    Q91YT7_PTM-0253_4
# 21  2009         phosphoserine      PTM-0253    Q91YT7_PTM-0253_5
# 22  2005         phosphoserine      PTM-0253   Q91YT7_PTM-0253_22

# %%
# save the dataframe as csv file
#df_modres_ref.to_csv('kgdata/df_modres_ref.csv', index=False)

# %%
# save the dataframe as json file
df_modres_ref.to_json('data/kgdata/df_modres_ref.json', orient='records')

# %%
df_modres_ref.columns
# Out:
# Index(['gene', 'name', 'organism', 'uniprotId', 'position', 'description',
#        'evidence', 'pubmedId', 'journal', 'title', 'date', 'Identifier',
#        'ptm_accession', 'mod_res_id'],
#       dtype='object')

# %% [markdown]
# # Rough

# %%
# explode the dictionaries into separate rows
#df_test = pd.read_csv('output/ptm_data.csv')
#df_test = df_test.explode('ptm')
#df_test.head(5)

# %%
# convert the dictionaries into separate columns
#df_test = pd.read_csv('output/ptm_data.csv')
#df_test[['Position', 'Description', 'Evidence']] = pd.json_normalize(df_test['ptm'])
